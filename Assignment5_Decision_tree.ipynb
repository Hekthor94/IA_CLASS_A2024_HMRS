# %% [markdown]
# <a href="https://colab.research.google.com/github/Hekthor94/IA_CLASS_A2024_HMRS/blob/main/Assignment5_Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Decision tree.**
# Name: Héctor Maximiliano Ramos Salazar\
# ID: 2007690\
# Class time: Tuesday N4-N6\

# %%
# 1. Load Libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# %%
# 2. Load Data
data = load_breast_cancer()
X = data.data
y = data.target

# %%
# 3. Data Preprocessing (split into training and testing sets)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# 4. Model Selection and Training (Desicion Tree)
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# 5. Model Testing
y_pred = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 95.61%

# %%
# Classification report
report = classification_report(y_test, y_pred, target_names=data.target_names)
print("\nClassification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#    malignant       0.97      0.90      0.94        42
#       benign       0.95      0.99      0.97        72
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
# Visualizing the decision tree
plt.figure(figsize=(15, 10), dpi=300)
plot_tree(model, filled=True, feature_names=data.feature_names, class_names=data.target_names, rounded=True)
plt.show()
